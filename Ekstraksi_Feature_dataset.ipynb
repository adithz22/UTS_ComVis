# %%
import os
import cv2
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = "/content/valid_dataset/valid"

# %%
def extract_features_simple(image):
    image = cv2.resize(image, (128, 128))

    # Convert ke HSV
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    mean_h = np.mean(hsv[:, :, 0])
    mean_s = np.mean(hsv[:, :, 1])
    mean_v = np.mean(hsv[:, :, 2])

    # Texture sederhana
    texture = np.std(image)

    return [mean_h, mean_s, mean_v, texture]

# %%
data = []
labels = []

for label in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, label)

    if os.path.isdir(folder_path):
        for file in os.listdir(folder_path):
            img_path = os.path.join(folder_path, file)

            image = cv2.imread(img_path)

            if image is not None:
                features = extract_features(image)

                data.append(features)
                labels.append(label)

# %%
columns = ["R", "G", "B", "H", "S", "V", "Texture"]

df = pd.DataFrame(data, columns=columns)
df["label"] = labels

# %%
csv_path = "/content/drive/MyDrive/banana_ekstraksi_fitur.csv"
df.to_csv(csv_path, index=False)

print("CSV berhasil disimpan di:", csv_path)
# Out:
# CSV berhasil disimpan di: /content/drive/MyDrive/banana_ekstraksi_fitur.csv
